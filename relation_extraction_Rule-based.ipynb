# %% [markdown]
# # Rule-based Relation Extraction

# %% [markdown]
# Here is a rule-based method which performs heuristic search of subject-attribute entity pairs from the NER result.

# %%
import pandas as pd
import ast
from nltk import pos_tag
from nltk.chunk import conlltags2tree
from nltk.tree import Tree

# %% [markdown]
# ## Utility functions

# %%
# BIO tags
def tag(ner_result):
    tags = []
    for word in ner_result:
        # print('word, ', word)
        if 'SEP' not in word['tag'] and 'CLS' not in word['tag'] :    #bert large may return 'CLS' tag
            tags.append((word['word'], word['tag']))
    return tags

# %%
# Create tree
def stanford_tree(bio_tagged):
    if len(bio_tagged) != 0:
        tokens, ne_tags = zip(*bio_tagged)
        pos_tags = [pos for token, pos in pos_tag(tokens)]

        conlltags = [(token, pos, ne) for token, pos, ne in zip(tokens, pos_tags, ne_tags)]
        ne_tree = conlltags2tree(conlltags)
        return ne_tree
    else:
        return None

# %%
# Parse named entities from tree
def structure_ne(ne_tree):
    if ne_tree is not None:
        ne = []
        for subtree in ne_tree:
            if type(subtree) == Tree:
                ne_label = subtree.label()
                ne_string = " ".join([token for token, pos in subtree.leaves()])
                ne.append((ne_string, ne_label))
        return ne
    else:
        return None

# %%
def find_index(mentions, s):
    index=0
    indexes=[]
    for mention in mentions:
        if mention in s:
            c = mention[0]
            # for ch in s:
            # Iterate over index
            for i in range(index, len(s)):            
                if s[i]==c:
                    if s[i:i+len(mention)] == mention:
                        indexes.append((mention,i,i+len(mention)))
                        index = i+len(mention)
                        break
    return indexes

# %%
# Apply relation extraction on the NER result
def call_RE_neighborpairs(df_ner):
    
    df_ner = df_ner[['#nct_id','eligibility_type','criterion','NER']]    
    df_ner = df_ner.drop_duplicates()
    
    result_ner = df_ner['NER']
    
    doc_index = df_ner['#nct_id']
    result_re = []
    for ner in result_ner:
        if isinstance(ner, str):
            ner = ast.literal_eval(ner)
        words = tag(ner)
        
        text=""
        for word in words:
            token = word[0]
            text+=token+" "
        
        tags_formatted = structure_ne(stanford_tree(words))
        mentions=[]
        tags=[]
        for one in tags_formatted:
            mentions.append(one[0])
            tags.append(one[1])
        
        indexes = find_index(mentions,text)
        # print(text)
        # print(indexes)
                
        entitylist=[]
        # 3:6:age,7:14:upper_bound	< age @NUMBER
        string=""
        for i in range(0,len(indexes)):
            mention=indexes[i][0]
            start=indexes[i][1]
            end=indexes[i][2]
            label=tags[i]
            string+= str(start)+":"+str(end)+":"+label +","
                        
            #entitylist.append((mention,label,start,end))
            entitylist.append((mention,label))

        string+="\t"+text
        # print(string)
                
        # generate relation statements
        relations=[]
        for i in range(len(entitylist)):
            if 'bound' in entitylist[i][1]:
                # print("index: ", i)
                left=entitylist[:i]

                # Find the neareast entity type on the left (of _bound)
                # find first element in a list with condition
                a = next((x for x in reversed(left) if x[1] in ["clinical_variable",'bmi','age']), None)        
                if a != None:
                    # print("nearby left: has value ", a, entitylist[i])
                    relations.append(('hasValue',a,entitylist[i]))
                b = next((x for x in reversed(left) if x[1] in ["allergy_name","cancer","chronic_disease","pregnancy",'treatment']), None)
                if a==None and b!=None:
                    # print("nearby left: has temp ", b, entitylist[i])
                    relations.append(('hasTemp',b,entitylist[i]))

                # Find the neareast entity type on the right (of _bound); if nothing on the left
                if(a==None and b==None):
                    right=entitylist[i:]
                    c = next((x for x in right if x[1] in ["clinical_variable",'bmi','age']), None)        
                    if c != None:
                        # print("nearby right: has value ", entitylist[i], c)
                        relations.append(('hasValue',entitylist[i],c))
                    d = next((x for x in right if x[1] in ["allergy_name","cancer","chronic_disease","pregnancy",'treatment']), None)
                    if c==None and d!=None:
                        print("nearby right: has temp ", entitylist[i], d)
                        relations.append(('hasTemp',entitylist[i],d))
            
        result_re.append(relations)
    
    print(len(df_ner))
    print(len(result_re))
    df_ner['Relation'] = result_re
    
    #reformat the relation statements
    df_re = df_ner[['#nct_id','eligibility_type','criterion','Relation']]
    df_re = df_re.explode('Relation')
    
    df_re[['RelationType', 'Entity1', 'Entity2']] = pd.DataFrame(df_re['Relation'].tolist(), index=df_re.index)
    
    df_re = df_re[['#nct_id','eligibility_type','criterion','RelationType','Entity1','Entity2']]
    
    return df_re

# %% [markdown]
# ## Do relation extraction using sample data

# %%
# Load sample NER data
df_ner = pd.read_excel('data_ner/sample_trial_NER.xlsx')
df_ner
# Out:
#         #nct_id eligibility_type  \
# 0   NCT00097734        inclusion
# 1   NCT00097734        inclusion
# 2   NCT00097734        inclusion
# 3   NCT00097734        inclusion
# 4   NCT00097734        inclusion
# 5   NCT00097734        inclusion
# 6   NCT00097734        inclusion
# 7   NCT00097734        inclusion
# 8   NCT00097734        inclusion
# 9   NCT00097734        inclusion
# 10  NCT00097734        inclusion
# 11  NCT00097734        inclusion
# 12  NCT00097734        inclusion
# 13  NCT00097734        inclusion
# 14  NCT00097734        inclusion
# 15  NCT00097734        inclusion
# 16  NCT00097734        exclusion
# 17  NCT00097734        exclusion
# 18  NCT00097734        exclusion
# 19  NCT00097734        exclusion
# 20  NCT00097734        exclusion
# 21  NCT00097734        exclusion
# 22  NCT00097734        exclusion
# 23  NCT00097734        exclusion
# 24  NCT00097734        exclusion
# 25  NCT00097734        exclusion
# 26  NCT00097734        exclusion
# 27  NCT00097734        exclusion
# 28  NCT00097734        exclusion
# 29  NCT00097734        exclusion
# 30  NCT00097734        exclusion
# 31  NCT00097734        exclusion
# 32  NCT00097734        exclusion
# 33  NCT00097734        exclusion
# 34  NCT00097734        exclusion
# 35  NCT00097734        exclusion
#
#                                             criterion  \
# 0   - At least three of the following signs or sym...
# 1   - At least three of the following signs or sym...
# 2   - At least three of the following signs or sym...
# 3   - At least three of the following signs or sym...
# 4   - At least three of the following signs or sym...
# 5   - At least three of the following signs or sym...
# 6   - At least three of the following signs or sym...
# 7   - At least three of the following signs or sym...
# 8   - At least three of the following signs or sym...
# 9   - At least three of the following signs or sym...
# 10  - At least three of the following signs or sym...
# 11  - At least three of the following signs or sym...
# 12  - CT evidence of wall thickening in the sigmoi...
# 13  - Decision in favor of conservative therapy on...
# 14  - Evidence of sigmoid diverticulitis by contra...
# 15  - Evidence of sigmoid diverticulitis by contra...
# 16  - Antibiotic therapy in the two weeks prior to...
# 17  - Antibiotic therapy in the two weeks prior to...
# 18  - Complications of sigmoid diverticulitis lead...
# 19  - Complications of sigmoid diverticulitis lead...
# 20  - Contraindication for the use of the study me...
# 21  - Contraindication for the use of the study me...
# 22  - Contraindication for the use of the study me...
# 23  - Contraindication for the use of the study me...
# 24  - Each patient can be enrolled only once in th...
# 25  - Female patients who are pregnant or nursing ...
# 26  - Female patients who are pregnant or nursing ...
# 27  - Female patients who are pregnant or nursing ...
# 28  - Participation in another clinical study or u...
# 29  - Participation in another clinical study or u...
# 30  - Participation in another clinical study or u...
# 31                   - Patients on immunosuppressants
# 32  - Patients with a hematologic/oncologic diseas...
# 33  - Patients with a hematologic/oncologic diseas...
# 34  - Patients with a hematologic/oncologic diseas...
# 35      - Patients with an advanced incurable disease
#
#                                                   NER  \
# 0   [{'word': '-', 'tag': 'O', 'confidence': 0.999...
# 1   [{'word': '-', 'tag': 'O', 'confidence': 0.999...
# 2   [{'word': '-', 'tag': 'O', 'confidence': 0.999...
# 3   [{'word': '-', 'tag': 'O', 'confidence': 0.999...
# 4   [{'word': '-', 'tag': 'O', 'confidence': 0.999...
# 5   [{'word': '-', 'tag': 'O', 'confidence': 0.999...
# 6   [{'word': '-', 'tag': 'O', 'confidence': 0.999...
# 7   [{'word': '-', 'tag': 'O', 'confidence': 0.999...
# 8   [{'word': '-', 'tag': 'O', 'confidence': 0.999...
# 9   [{'word': '-', 'tag': 'O', 'confidence': 0.999...
# 10  [{'word': '-', 'tag': 'O', 'confidence': 0.999...
# 11  [{'word': '-', 'tag': 'O', 'confidence': 0.999...
# 12  [{'word': '-', 'tag': 'O', 'confidence': 0.999...
# 13  [{'word': '-', 'tag': 'O', 'confidence': 0.999...
# 14  [{'word': '-', 'tag': 'O', 'confidence': 0.999...
# 15  [{'word': '-', 'tag': 'O', 'confidence': 0.999...
# 16  [{'word': '-', 'tag': 'O', 'confidence': 0.999...
# 17  [{'word': '-', 'tag': 'O', 'confidence': 0.999...
# 18  [{'word': '-', 'tag': 'O', 'confidence': 0.999...
# 19  [{'word': '-', 'tag': 'O', 'confidence': 0.999...
# 20  [{'word': '-', 'tag': 'O', 'confidence': 0.999...
# 21  [{'word': '-', 'tag': 'O', 'confidence': 0.999...
# 22  [{'word': '-', 'tag': 'O', 'confidence': 0.999...
# 23  [{'word': '-', 'tag': 'O', 'confidence': 0.999...
# 24  [{'word': '-', 'tag': 'O', 'confidence': 0.999...
# 25  [{'word': '-', 'tag': 'O', 'confidence': 0.999...
# 26  [{'word': '-', 'tag': 'O', 'confidence': 0.999...
# 27  [{'word': '-', 'tag': 'O', 'confidence': 0.999...
# 28  [{'word': '-', 'tag': 'O', 'confidence': 0.999...
# 29  [{'word': '-', 'tag': 'O', 'confidence': 0.999...
# 30  [{'word': '-', 'tag': 'O', 'confidence': 0.999...
# 31  [{'word': '-', 'tag': 'O', 'confidence': 0.999...
# 32  [{'word': '-', 'tag': 'O', 'confidence': 0.999...
# 33  [{'word': '-', 'tag': 'O', 'confidence': 0.999...
# 34  [{'word': '-', 'tag': 'O', 'confidence': 0.999...
# 35  [{'word': '-', 'tag': 'O', 'confidence': 0.999...
#
#                                                  Tags  \
# 0                            ('three', 'lower_bound')
# 1       ('sigmoid diverticulitis', 'chronic_disease')
# 2                        ('Fever', 'chronic_disease')
# 3           ('body temperature', 'clinical_variable')
# 4                             ('38°C', 'lower_bound')
# 5                 ('Leukocytosis', 'chronic_disease')
# 6                 ('leukocytes', 'clinical_variable')
# 7                        ('10,000/µl', 'lower_bound')
# 8   ('differential blood count', 'clinical_variable')
# 9                              ('1 %', 'lower_bound')
# 10              ('Elevated CRP', 'clinical_variable')
# 11                         ('20 mg/l', 'lower_bound')
# 12                                                NaN
# 13              ('conservative therapy', 'treatment')
# 14      ('sigmoid diverticulitis', 'chronic_disease')
# 15                             ('enema', 'treatment')
# 16                ('Antibiotic therapy', 'treatment')
# 17                 ('two weeks prior', 'upper_bound')
# 18      ('sigmoid diverticulitis', 'chronic_disease')
# 19                           ('surgery', 'treatment')
# 20                        ('medication', 'treatment')
# 21           ('beta-lactam antibiotics', 'treatment')
# 22            ('renal impairment', 'chronic_disease')
# 23                      ('hemodialysis', 'treatment')
# 24                                                NaN
# 25                      ('Female patients', 'gender')
# 26                      ('are pregnant', 'pregnancy')
# 27                            ('become', 'pregnancy')
# 28            ('another clinical study', 'treatment')
# 29                        ('study drug', 'treatment')
# 30                ('four weeks prior', 'upper_bound')
# 31                ('immunosuppressants', 'treatment')
# 32  ('hematologic/oncologic disease', 'chronic_dis...
# 33                             ('leukemia', 'cancer')
# 34                             ('lymphoma', 'cancer')
# 35  ('advanced incurable disease', 'chronic_disease')
#
#                            Entity               Type
# 0                           three        lower_bound
# 1          sigmoid diverticulitis    chronic_disease
# 2                           Fever    chronic_disease
# 3                body temperature  clinical_variable
# 4                            38°C        lower_bound
# 5                    Leukocytosis    chronic_disease
# 6                      leukocytes  clinical_variable
# 7                       10,000/µl        lower_bound
# 8        differential blood count  clinical_variable
# 9                             1 %        lower_bound
# 10                   Elevated CRP  clinical_variable
# 11                        20 mg/l        lower_bound
# 12                            NaN               None
# 13           conservative therapy          treatment
# 14         sigmoid diverticulitis    chronic_disease
# 15                          enema          treatment
# 16             Antibiotic therapy          treatment
# 17                two weeks prior        upper_bound
# 18         sigmoid diverticulitis    chronic_disease
# 19                        surgery          treatment
# 20                     medication          treatment
# 21        beta-lactam antibiotics          treatment
# 22               renal impairment    chronic_disease
# 23                   hemodialysis          treatment
# 24                            NaN               None
# 25                Female patients             gender
# 26                   are pregnant          pregnancy
# 27                         become          pregnancy
# 28         another clinical study          treatment
# 29                     study drug          treatment
# 30               four weeks prior        upper_bound
# 31             immunosuppressants          treatment
# 32  hematologic/oncologic disease    chronic_disease
# 33                       leukemia             cancer
# 34                       lymphoma             cancer
# 35     advanced incurable disease    chronic_disease

# %%
# Input is the NER result
df_relations = call_RE_neighborpairs(df_ner)
# Out:
# 13
# 13

# %%
df_relations
# Out:
#         #nct_id eligibility_type  \
# 0   NCT00097734        inclusion
# 0   NCT00097734        inclusion
# 0   NCT00097734        inclusion
# 0   NCT00097734        inclusion
# 0   NCT00097734        inclusion
# 12  NCT00097734        inclusion
# 13  NCT00097734        inclusion
# 14  NCT00097734        inclusion
# 16  NCT00097734        exclusion
# 18  NCT00097734        exclusion
# 20  NCT00097734        exclusion
# 24  NCT00097734        exclusion
# 25  NCT00097734        exclusion
# 28  NCT00097734        exclusion
# 31  NCT00097734        exclusion
# 32  NCT00097734        exclusion
# 35  NCT00097734        exclusion
#
#                                             criterion RelationType  \
# 0   - At least three of the following signs or sym...     hasValue
# 0   - At least three of the following signs or sym...     hasValue
# 0   - At least three of the following signs or sym...     hasValue
# 0   - At least three of the following signs or sym...     hasValue
# 0   - At least three of the following signs or sym...     hasValue
# 12  - CT evidence of wall thickening in the sigmoi...          NaN
# 13  - Decision in favor of conservative therapy on...          NaN
# 14  - Evidence of sigmoid diverticulitis by contra...          NaN
# 16  - Antibiotic therapy in the two weeks prior to...      hasTemp
# 18  - Complications of sigmoid diverticulitis lead...          NaN
# 20  - Contraindication for the use of the study me...          NaN
# 24  - Each patient can be enrolled only once in th...          NaN
# 25  - Female patients who are pregnant or nursing ...          NaN
# 28  - Participation in another clinical study or u...      hasTemp
# 31                   - Patients on immunosuppressants          NaN
# 32  - Patients with a hematologic/oncologic diseas...          NaN
# 35      - Patients with an advanced incurable disease          NaN
#
#                                           Entity1  \
# 0                            (three, lower_bound)
# 0           (body temperature, clinical_variable)
# 0                 (leukocytes, clinical_variable)
# 0   (differential blood count, clinical_variable)
# 0               (Elevated CRP, clinical_variable)
# 12                                           None
# 13                                           None
# 14                                           None
# 16                (Antibiotic therapy, treatment)
# 18                                           None
# 20                                           None
# 24                                           None
# 25                                           None
# 28                        (study drug, treatment)
# 31                                           None
# 32                                           None
# 35                                           None
#
#                                   Entity2
# 0   (body temperature, clinical_variable)
# 0                     (38°C, lower_bound)
# 0                (10,000/µl, lower_bound)
# 0                      (1 %, lower_bound)
# 0                  (20 mg/l, lower_bound)
# 12                                   None
# 13                                   None
# 14                                   None
# 16         (two weeks prior, upper_bound)
# 18                                   None
# 20                                   None
# 24                                   None
# 25                                   None
# 28        (four weeks prior, upper_bound)
# 31                                   None
# 32                                   None
# 35                                   None

# %%
df_relations.to_excel("data_re/sample_trial_relations_Rule-prediction.xlsx", index=False, encoding='utf8')
